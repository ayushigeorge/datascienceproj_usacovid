# %%
conda install seaborn
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv(r"C:\Users\Admin\Desktop\data\national-history.csv")

# %%
data.head()
# Out:
#          date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0  07-03-2021  515151.0            842          45475.0          8134.0
# 1  06-03-2021  514309.0           1680          45453.0          8409.0
# 2  05-03-2021  512629.0           2221          45373.0          8634.0
# 3  04-03-2021  510408.0           1743          45293.0          8970.0
# 4  03-03-2021  508665.0           2449          45214.0          9359.0
#
#    hospitalizedIncrease  hospitalizedCurrently  hospitalizedCumulative  \
# 0                   726                40199.0                776361.0
# 1                   503                41401.0                775635.0
# 2                  2781                42541.0                775132.0
# 3                  1530                44172.0                772351.0
# 4                  2172                45462.0                770821.0
#
#      negative  negativeIncrease  onVentilatorCumulative  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'death', 'deathIncrease', 'inIcuCumulative', 'inIcuCurrently',
#        'hospitalizedIncrease', 'hospitalizedCurrently',
#        'hospitalizedCumulative', 'negative', 'negativeIncrease',
#        'onVentilatorCumulative', 'onVentilatorCurrently', 'positive',
#        'positiveIncrease', 'states', 'totalTestResults',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %%
data.tail
# Out:
# <bound method NDFrame.tail of            date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0    07-03-2021  515151.0            842          45475.0          8134.0
# 1    06-03-2021  514309.0           1680          45453.0          8409.0
# 2    05-03-2021  512629.0           2221          45373.0          8634.0
# 3    04-03-2021  510408.0           1743          45293.0          8970.0
# 4    03-03-2021  508665.0           2449          45214.0          9359.0
# ..          ...       ...            ...              ...             ...
# 415  17-01-2020       NaN              0              NaN             NaN
# 416  16-01-2020       NaN              0              NaN             NaN
# 417  15-01-2020       NaN              0              NaN             NaN
# 418  14-01-2020       NaN              0              NaN             NaN
# 419  13-01-2020       NaN              0              NaN             NaN
#
# ...

# %%
data.describe()
# Out:
#                death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# count     392.000000     420.000000       348.000000      347.000000
# mean   187210.668367    1226.550000     21059.344828    12059.227666
# std    142331.657380    1070.129644     13572.638376     5668.415483
# min         0.000000       0.000000        74.000000     1299.000000
# 25%     86911.750000     439.750000      9900.250000     7495.500000
# 50%    169118.500000    1016.000000     18797.500000    10114.000000
# 75%    258912.250000    1642.500000     32998.500000    15596.500000
# max    515151.000000    5427.000000     45475.000000    23912.000000
#
#        hospitalizedIncrease  hospitalizedCurrently  hospitalizedCumulative  \
# count            420.000000             356.000000              369.000000
# mean            1848.478571           57987.117978           310817.140921
# std             1708.460481           31898.555998           235557.870159
# ...

# %%
data.isnull().sum()
# Out:
# date                         0
# death                       28
# deathIncrease                0
# inIcuCumulative             72
# inIcuCurrently              73
# hospitalizedIncrease         0
# hospitalizedCurrently       64
# hospitalizedCumulative      51
# negative                    48
# negativeIncrease             0
# onVentilatorCumulative      79
# onVentilatorCurrently       72
# positive                     1
# positiveIncrease             0
# states                       0
# totalTestResults             0
# totalTestResultsIncrease     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['date', 'death', 'deathIncrease', 'inIcuCumulative', 'inIcuCurrently',
#        'hospitalizedIncrease', 'hospitalizedCurrently',
#        'hospitalizedCumulative', 'negative', 'negativeIncrease',
#        'onVentilatorCumulative', 'onVentilatorCurrently', 'positive',
#        'positiveIncrease', 'states', 'totalTestResults',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x ="death", y= "deathIncrease", data=data)

# %%
sns.relplot(x="hospitalizedCurrently", y="hospitalizedIncrease", data=data)

# %%
sns.relplot(x="hospitalizedCurrently", y="onVentilatorCumulative", data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['date', 'death', 'deathIncrease', 'inIcuCumulative', 'inIcuCurrently',
#        'hospitalizedIncrease', 'hospitalizedCurrently',
#        'hospitalizedCumulative', 'negative', 'negativeIncrease',
#        'onVentilatorCumulative', 'onVentilatorCurrently', 'positive',
#        'positiveIncrease', 'states', 'totalTestResults',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %%
sns.relplot( x='totalTestResultsIncrease', y='deathIncrease', kind='line', data=data)

# %%
data.columns
# Out:
# Index(['date', 'death', 'deathIncrease', 'inIcuCumulative', 'inIcuCurrently',
#        'hospitalizedIncrease', 'hospitalizedCurrently',
#        'hospitalizedCumulative', 'negative', 'negativeIncrease',
#        'onVentilatorCumulative', 'onVentilatorCurrently', 'positive',
#        'positiveIncrease', 'states', 'totalTestResults',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %%
sns.catplot(x='totalTestResultsIncrease', y='inIcuCurrently', data=data)
